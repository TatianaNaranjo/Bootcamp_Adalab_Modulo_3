# %% [markdown]
# # Pair Programming 27/05 Test Estadísticos III - Tatiana y Guada

# %%
import pandas as pd
import random 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

import researchpy as rp
import scipy.stats as stats
from scipy.stats import levene


plt.rcParams["figure.figsize"] = (10,8)

# %% [markdown]
# Usaremos el dataset de listings_limpio-2 en el caso que no hayamos llegado a terminar el pair de ayer. Si tenéis el csv de ayer es preferido que uséis ese.

# %%
df = pd.read_csv("listing_nuevo2.csv", index_col=0)
df.head(2)
# Out:
#   neighbourhood_group     room_type  price  minimum_nights  number_of_reviews  \
# 0           Chamartín  Private room     59               1                 81
# 1              Latina  Private room     31               4                 33
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 0                               1               149                      3
# 1                               2               131                      0

# %% [markdown]
# # Ejercicio 1
# Chequead los outliers y haced la gestión de ellos, como aprendimos en las lecciones de limpieza.

# %%
numericas = df.select_dtypes(include=['int64', 'float64'])

fig, axes = plt.subplots(6, 1, figsize=(15,25))

for i in range(len(numericas.columns)):
    sns.boxplot(x = numericas.columns[i], data = df, ax=axes[i]); # para trazar una línea de densidad

plt.show()

# %%
def detectar_outliers(lista_columnas, dataframe):
    dicc_indices = {} # creamos un diccionario donde almacenaremos índices de los outliers
    # iteramos por la lista de las columnas numéricas de nuestro dataframe
    for col in lista_columnas:
        #calculamos los cuartiles Q1 y Q3
        Q1 = np.nanpercentile(df[col], 25)
        Q3 = np.nanpercentile(df[col], 75)
        # calculamos el rango intercuartil
        IQR = Q3 - Q1
        # calculamos los límites
        outlier_step = 1.5 * IQR
        # filtramos nuestro dataframe para indentificar los outliers
        outliers_data = dataframe[(dataframe[col] < Q1 - outlier_step) | (dataframe[col] > Q3 + outlier_step)]
        if outliers_data.shape[0] > 0: # chequeamos si nuestro dataframe tiene alguna fila.
            dicc_indices[col] = (list(outliers_data.index)) # si tiene fila es que hay outliers y por lo tanto lo añadimos a nuestro diccionario
    return dicc_indices

# %%
numericas.median()
# Out:
# price                              71.0
# minimum_nights                      2.0
# number_of_reviews                   8.0
# calculated_host_listings_count      2.0
# availability_365                  113.0
# number_of_reviews_ltm               1.0
# dtype: float64

# %%
ind = detectar_outliers(numericas, df)
ind.keys()
# Out:
# dict_keys(['price', 'minimum_nights', 'number_of_reviews', 'calculated_host_listings_count', 'number_of_reviews_ltm'])

# %%
df["room_type"].value_counts()
# Out:
# Entire home/apt    10588
# Private room        6197
# Shared room          225
# Hotel room           133
# Name: room_type, dtype: int64

# %%
# hacemos un for loop para iterar por el diccionario y acceder a las columnas y filas 
# y reemplazar los valores por la mediana

for k, v in ind.items():
    
    median = df[k].median()
   
    for i in v: 
            df.loc[i,k] = median
    else:
        pass

# %%
df.describe()
# Out:
#               price  minimum_nights  number_of_reviews  \
# count  17143.000000    17143.000000       17143.000000
# mean      74.991425        2.000467          15.190048
# std       44.507680        1.086021          21.770478
# min        7.000000        1.000000           0.000000
# 25%       40.000000        1.000000           1.000000
# 50%       71.000000        2.000000           8.000000
# 75%       97.000000        2.000000          19.000000
# max      225.000000        6.000000          98.000000
#
#        calculated_host_listings_count  availability_365  number_of_reviews_ltm
# count                    17143.000000      17143.000000           17143.000000
# mean                         2.851135        150.251240               2.871143
# std                          3.010735        139.254279               4.676555
# min                          1.000000          0.000000               0.000000
# 25%                          1.000000          0.000000               0.000000
# 50%                          2.000000        113.000000               1.000000
# 75%                          3.000000        309.000000               4.000000
# max                         16.000000        365.000000              20.000000

# %% [markdown]
# # Ejercicio 2
# ¿Sigue la columma price una distribución normal? Chequeadlo visual y analiticamente.
# En caso de que no siga una distribución normal, realizad la transformación necesaria para que se ajuste a una normal.

# %%
sns.histplot(df["price"],  bins=20);

# %% [markdown]
# 👩🏻👩🏻‍🦰💬
#
# Visualmente comprobamos que no tiene una distribución normal, ya que no tiene forma de campana de Gauss

# %%
stats.shapiro(df["price"].sample(5000))
# Out:
# ShapiroResult(statistic=0.9258196949958801, pvalue=2.5223372357846707e-44)

# %%
df["price"], lambda_ajustada = stats.boxcox(df["price"])

# %%
sns.histplot(df["price"],  bins=15);

# %% [markdown]
# 👩🏻👩🏻‍🦰💬
#
# Visualmente comprobamos que ahora si tiene una distribución normal.

# %% [markdown]
# # Ejercicio 3
# Chequead la independencia entre las siguientes columnas: neighbourhood_group y room_type

# %%
crosstab, test_results, expected = rp.crosstab(df["neighbourhood_group"], df["room_type"],
                                               test= "chi-square",
                                               expected_freqs= True,
                                               prop= "cell")

# %%
crosstab.head()
# Out:
#                           room_type
# room_type           Entire home/apt Hotel room Private room Shared room    All
# neighbourhood_group
# Arganzuela                     3.30       0.01         2.22        0.02   5.54
# Barajas                        0.25       0.00         0.53        0.01   0.79
# Carabanchel                    1.41       0.01         2.02        0.02   3.46
# Centro                        33.41       0.59        10.74        0.64  45.38
# Chamartín                      1.79       0.02         1.07        0.03   2.91

# %%
test_results
# Out:
#                  Chi-square test    results
# 0  Pearson Chi-square ( 60.0) =   1843.7483
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.1893

# %% [markdown]
# 👩🏻👩🏻‍🦰💬
#
# Como vemos en la tabla de arriba, nuestro Cramer´s V es 0.18, lo que indica que nuestra independencia es baja.

# %% [markdown]
# # Ejercicio 4
# Chequead la heterocedasticidad de la columna room_type frente al price

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 6))

sns.boxplot(
    x       = 'room_type',
    y       = 'price',
    data    = df,
    palette = 'bright',
    ax      = ax
)
ax.set_title('Distribución de precios por tipo de habitación')
ax.set_xlabel('room_type')
ax.set_ylabel('price');

# %% [markdown]
# 👩🏻👩🏻‍🦰💬
#
# Podemos observar que en nuestro subsplot, los resultados son diferentes entre si, por lo que se aprecia la heterocedasticidad. La probabilidad real de cometer un error de tipo I es mayor que la devuelta por el test y los intervalos de confianza verdaderos serán más amplios que los calculados. Recordamos que el error tipo I sucede si rechazamos la hipótesis nula cuando es verdadera.

# %%
privada = df[df["room_type"] == 'Private room']["price"]
entera = df[df["room_type"] == 'Entire home/apt']["price"]
compartida = df[df["room_type"] == 'Shared room']["price"]
hotel = df[df["room_type"] == 'Hotel room']["price"]

# %%
df.room_type.unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room', 'Hotel room'],
#       dtype=object)

# %%
levene_test = stats.levene(privada, entera, compartida, hotel, center='median')
print(levene_test)

bartlett_test = stats.bartlett(privada, entera, compartida, hotel)
print(bartlett_test)

fligner_test = stats.fligner(privada, entera, compartida, hotel, center='median')
print(fligner_test)
# Out:
# LeveneResult(statistic=50.78144843838793, pvalue=1.1462486405691814e-32)
# BartlettResult(statistic=260.4778091939414, pvalue=3.5436076760771997e-56)
# FlignerResult(statistic=127.84347920167919, pvalue=1.5768074430812343e-27)

# %% [markdown]
# 👩🏻👩🏻‍🦰💬 p-value menor a 0.05,  Por lo tanto, la hipótesis nula de igualdad de varianzas se rechaza y se concluye que hay una diferencia entre las variaciones en el tipo de hospedaje
